# %%
agent_xs = [25.+50.*i for i in range(5)]
agent_ys = [15.+50.*i for i in range(5)]
map_bounds = [5*50., 5*50.]

# %%
map_bounds
# Out:
# [250.0, 250.0]

# %%
print('      rovers:')
for x in agent_xs:
    for y in agent_ys:
        print('        - action:')
        print('            type: dxdy')
        print('          observation_radius: 5.0')
        print('          policy:')
        print('            type: network')
        print('          position:')
        print('            fixed:')
        print('            - ',x)
        print('            - ',y)
        print('            spawn_rule: fixed')
        print('          resolution: 90')
        print('          reward_type: Global')
        print('          sensor:')
        print('            accum_type: sum')
        print('            type: SmartLidar')
# Out:
#       rovers:
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  25.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  25.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  25.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  25.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  25.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  75.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  75.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  75.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  75.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  75.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  125.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  125.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  125.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  125.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  125.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  175.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  175.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  175.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  175.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  175.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  225.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  225.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  225.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  225.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar
#         - action:
#             type: dxdy
#           observation_radius: 5.0
#           policy:
#             type: network
#           position:
#             fixed:
#             -  225.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             type: SmartLidar

# %%
print('      uavs:')
for x in agent_xs:
    for y in agent_ys:
        print('        - action:')
        print('           type: dxdy')
        print('          observation_radius: 100.0')
        print('          position:')
        print('            fixed:')
        print('            - ',x)
        print('            - ',y)
        print('            spawn_rule: fixed')
        print('          resolution: 90')
        print('          reward_type: Global')
        print('          sensor:')
        print('            accum_type: sum')
        print('            default_value: 0.0')
        print('            measurement_type: one_minus_inverse_distance_over_observation_radius')
        print('            type: SmartLidar')
# Out:
#       uavs:
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  25.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  25.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  25.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  25.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  25.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  75.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  75.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  75.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  75.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  75.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  125.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  125.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  125.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  125.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  125.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  175.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  175.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  175.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  175.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  175.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  225.0
#             -  15.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  225.0
#             -  65.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  225.0
#             -  115.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  225.0
#             -  165.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar
#         - action:
#            type: dxdy
#           observation_radius: 100.0
#           position:
#             fixed:
#             -  225.0
#             -  215.0
#             spawn_rule: fixed
#           resolution: 90
#           reward_type: Global
#           sensor:
#             accum_type: sum
#             default_value: 0.0
#             measurement_type: one_minus_inverse_distance_over_observation_radius
#             type: SmartLidar

# %%
print('      env:pois:hidden_pois:')
for x in agent_xs:
        for y in agent_ys:
            print('        - capture_radius: 5.0')
            print('          constraint: sequential')
            print('          coupling: 1')
            print('          observation_radius: 5.0')
            print('          position:')
            print('            random_circle:')
            print(f'              center: [{x}, {y}]')
            print('              radius: 10.0')
            print('            spawn_rule: random_circle')
            print('          value: 1.0')
# Out:
#       env:pois:hidden_pois:
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [25.0, 15.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [25.0, 65.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [25.0, 115.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [25.0, 165.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [25.0, 215.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [75.0, 15.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [75.0, 65.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [75.0, 115.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [75.0, 165.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [75.0, 215.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [125.0, 15.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [125.0, 65.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [125.0, 115.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [125.0, 165.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [125.0, 215.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [175.0, 15.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [175.0, 65.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [175.0, 115.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [175.0, 165.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [175.0, 215.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [225.0, 15.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [225.0, 65.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [225.0, 115.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [225.0, 165.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
#         - capture_radius: 5.0
#           constraint: sequential
#           coupling: 1
#           observation_radius: 5.0
#           position:
#             random_circle:
#               center: [225.0, 215.0]
#               radius: 10.0
#             spawn_rule: random_circle
#           value: 1.0
